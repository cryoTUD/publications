# %%
import os 
import subprocess
# Out:
# Running cells with 'locscalesurfer' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n locscalesurfer ipykernel --update-deps --force-reinstall'

# %%
main_folder = "/home/abharadwaj1/thesis/data_archive/inputs/3_surfer/low_pass_filtered/emd_33888"
mask_path = os.path.join(main_folder, "EMD_33888_unsharpened_fullmap_confidenceMap.mrc")

locscalesurfer = "/home/abharadwaj1/dev/gitrepo/locscale-surfer/locscale_surfer.py"
# Out:
# Running cells with 'locscalesurfer' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n locscalesurfer ipykernel --update-deps --force-reinstall'

# %%
cutoff_res = [5, 6, 7, 8, 9, 10, 15, 20, 25]
for cutoff in cutoff_res:
    subfolder_path = os.path.join(main_folder, f"low_pass_{cutoff}A")
    emmap_path = os.path.join(subfolder_path, f"emd_33888_filtered_{cutoff}A.mrc")
    cmd = ["python"]
    cmd.append[locscalesurfer]
    cmd.append("--input")
    cmd.append(emmap_path)
    cmd.append("--mask_path")
    cmd.append(mask_path)
    cmd.append("--gpu_ids")
    cmd.append(["6", "7"])
    print(f"Running LocScale Surfer for cutoff {cutoff}A...")
    try: 
        output_text = os.path.join(subfolder_path, f"locscale_surfer_output_{cutoff}A.txt")
        with open(output_text, "w") as f:
            subprocess.run(cmd, stdout=f, stderr=subprocess.STDOUT)
    except Exception as e:
        print(f"Error running LocScale Surfer for cutoff {cutoff}A: {e}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9712/2816733641.py in <module>
#       4     emmap_path = os.path.join(subfolder_path, f"emd_33888_filtered_{cutoff}A.mrc")
#       5     cmd = ["python"]
# ----> 6     cmd.append[""]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
